# %% [markdown]
# # Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## The plot Method
# - By default, the `plot` method renders a line chart, which is ideal for showing trends over time.
# - The `plot` method includes all numeric **DataFrame** columns by default. We can choose a subset with the `y` parameter.
# - Matplotlib will use the index values for the x-axis and the values for the y-axis.
# - Matplotlib will figure out reasonable intervals for the date index (days, months, years, etc.). These options are all customizable.

# %%
ibm= pd.read_csv('ibm.csv', parse_dates=['Date'], date_format='%Y-%m-%d', index_col='Date')
ibm.head()
# Out:
#                Open     High      Low    Close         Volume
# Date
# 1962-01-02  5.04610  5.04610  4.98716  4.98716  593562.955237
# 1962-01-03  4.98716  5.03292  4.98716  5.03292  445175.034277
# 1962-01-04  5.03292  5.03292  4.98052  4.98052  399513.586679
# 1962-01-05  4.97389  4.97389  4.87511  4.88166  559321.480565
# 1962-01-08  4.88166  4.88166  4.75059  4.78972  833273.771393

# %%
ibm.plot()
plt.show(ibm.plot(y= 'Close'))
plt.show(ibm['Close'].plot())

# %% [markdown]
# ## Modifying Plot Aesthetics with Templates
# - The `plt.style.available` attribute returns a list of available styles.
# - Use the `plt.style.use` method and pass in a sample style string.
# - The next charts/graphs you render will implement that style.

# %%
ibm= pd.read_csv('ibm.csv', parse_dates=['Date'], date_format='%Y-%m-%d', index_col='Date')
ibm.head()
# Out:
#                Open     High      Low    Close         Volume
# Date
# 1962-01-02  5.04610  5.04610  4.98716  4.98716  593562.955237
# 1962-01-03  4.98716  5.03292  4.98716  5.03292  445175.034277
# 1962-01-04  5.03292  5.03292  4.98052  4.98052  399513.586679
# 1962-01-05  4.97389  4.97389  4.87511  4.88166  559321.480565
# 1962-01-08  4.88166  4.88166  4.75059  4.78972  833273.771393

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('classic')
ibm['Volume'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
plt.style.use('bmh')
ibm.plot(y= 'Volume')
# Out:
# <Axes: xlabel='Date'>

# %%
plt.style.use('ggplot')
ibm['Low'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Bar Charts
# - A bar chart uses bars to represent occurrences of values/categories.
# - We can customize the type of plot that matplotlib renders with the `kind` parameter.
# - Pass `bar` for a bar graph and `barh` for a horizontal bar graph.

# %%
ibm= pd.read_csv('ibm.csv', parse_dates=['Date'], date_format='%Y-%m-%d', index_col='Date')
ibm.head()
# Out:
#                Open     High      Low    Close         Volume
# Date
# 1962-01-02  5.04610  5.04610  4.98716  4.98716  593562.955237
# 1962-01-03  4.98716  5.03292  4.98716  5.03292  445175.034277
# 1962-01-04  5.03292  5.03292  4.98052  4.98052  399513.586679
# 1962-01-05  4.97389  4.97389  4.87511  4.88166  559321.480565
# 1962-01-08  4.88166  4.88166  4.75059  4.78972  833273.771393

# %%
def rank_performance(stock_price):
    if stock_price <= 50:
        return 'Poor'
    elif stock_price > 50 and stock_price <= 100:
        return 'Satisfactory'
    else:
        return 'Excellent'

ibm['Rank']= ibm['Close'].apply(rank_performance)
ibm.head()
# Out:
#                Open     High      Low    Close         Volume  Rank
# Date
# 1962-01-02  5.04610  5.04610  4.98716  4.98716  593562.955237  Poor
# 1962-01-03  4.98716  5.03292  4.98716  5.03292  445175.034277  Poor
# 1962-01-04  5.03292  5.03292  4.98052  4.98052  399513.586679  Poor
# 1962-01-05  4.97389  4.97389  4.87511  4.88166  559321.480565  Poor
# 1962-01-08  4.88166  4.88166  4.75059  4.78972  833273.771393  Poor

# %%
ibm['Rank'].value_counts()
# Out:
# Rank
# Poor            9423
# Excellent       3085
# Satisfactory    3038
# Name: count, dtype: int64

# %%
ibm.groupby('Rank')['Close'].count()
# Out:
# Rank
# Excellent       3085
# Poor            9423
# Satisfactory    3038
# Name: Close, dtype: int64

# %%
ibm.groupby('Rank')['Close'].count().plot(kind= 'bar')
# Out:
# <Axes: xlabel='Rank'>

# %%
ibm.groupby('Rank')['Close'].count().plot(kind= 'barh')
# Out:
# <Axes: ylabel='Rank'>

# %% [markdown]
# ## Pie Charts
# - A pie chart uses a circle to represent proportions (how much each chunk contributes to the whole).
# - Pass the `kind` parameter an argument of "pie".
# - The `legend` parameter renders a legend to map colors to labels.

# %%
ibm= pd.read_csv('ibm.csv', parse_dates=['Date'], date_format='%Y-%m-%d', index_col='Date')
ibm.head()
# Out:
#                Open     High      Low    Close         Volume
# Date
# 1962-01-02  5.04610  5.04610  4.98716  4.98716  593562.955237
# 1962-01-03  4.98716  5.03292  4.98716  5.03292  445175.034277
# 1962-01-04  5.03292  5.03292  4.98052  4.98052  399513.586679
# 1962-01-05  4.97389  4.97389  4.87511  4.88166  559321.480565
# 1962-01-08  4.88166  4.88166  4.75059  4.78972  833273.771393

# %%
average_stock_price= ibm['Close'].mean()
average_stock_price
# Out:
# 46.16316486491702

# %%
def rank_performance(stock_price):
    if stock_price >= average_stock_price:
        return 'Above Average'

    else: 
        return 'Below Average'

# %%
plt.style.use('fivethirtyeight')
ibm['Close'].apply(rank_performance).value_counts(normalize= True).plot(kind= 'pie', legend= True)
# Out:
# <Axes: ylabel='proportion'>

# %%
# matplotlib uses the index of your series/dataframe as the x-axis by default (but of course it can be changed)
